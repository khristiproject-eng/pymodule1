# %% [markdown]
# <a href="https://colab.research.google.com/github/khristiproject-eng/pymodule1/blob/main/gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls -lr drive/MyDrive/module1/
# Out:
# total 1
# -rw------- 1 root root 34 Mar 16 13:35 pytest.py

# %%
# !python /content/drive/MyDrive/module1/pytest.py
# Out:
# Hello Khristi from GitHub
